# %% [markdown]
# ## 1757. Recyclable and Low Fat Products
# '''
#
# Example 1:
#
# Input:
# Products table:
# +-------------+----------+------------+
# | product_id  | low_fats | recyclable |
# +-------------+----------+------------+
# | 0           | Y        | N          |
# | 1           | Y        | Y          |
# | 2           | N        | Y          |
# | 3           | Y        | Y          |
# | 4           | N        | N          |
# +-------------+----------+------------+
# Output:
# +-------------+
# | product_id  |
# +-------------+
# | 1           |
# | 3           |
# +-------------+
#
# Write a solution to find the ids of products that are both low fat and recyclable.
#
#
# '''

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import StructType,StructField,IntegerType,StringType,LongType

# %%
spark=SparkSession.builder.appName("LeetcodeSQL50").getOrCreate()
spark.version
# Out:
# 26/07/08 12:14:38 WARN Utils: Your hostname, Chinmayas-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 192.168.1.7 instead (on interface en0)
# 26/07/08 12:14:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/08 12:14:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/07/08 12:14:39 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# '3.5.7'
